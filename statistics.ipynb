# %% [markdown]
# # СТАТИСТИКА

# %% [markdown]
# Импорт библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps

# %% [markdown]
# ## Генерация распределений

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 0, дисперсия - 1). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Посчитать сколько значений находится в хвостах по 2,5% (теоретически соответствуют значениям - 1,96).

# %%
s[(s > 1.96) | (s < -1.96)].count()
# Out:
# 508

# %% [markdown]
# Построить плотность вероятности и функцию распределения этой серии

# %%
sns.kdeplot(s);
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sns.ecdfplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p = 0.2, size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %% [markdown]
# sns.histplot(s)

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(p = 0.5, n = 10, size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p = 0.4, size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Соответствуют ли частоты ожидаемым?

# %% [markdown]
# ## Закон больших чисел

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Из серии s выбрать 5 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 10.86999554452984

# %% [markdown]
# Сгенерировать список количеств отбираемых значений: [5, 10, 15, ..., 10000]

# %%
k = list(range(5, 10000, 5))

# %% [markdown]
# Для каждого значения из созданного списка посчитать среднее

# %%
q = []
for a in k:
    q.append(s.sample(a).mean())

# %% [markdown]
# Построить график: размер выборки - среднее

# %%
sns.lineplot(x = k, y = q)
sns.lineplot(x = k, y = sum(q)/len(q))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Центральная предельная теорема

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale = 3, size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 10.125652118892168

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
q = []
for a in range(10000):
    q.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(q)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(p=0.4, n=5, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 2.08

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
q = []
for a in range(10000):
    q.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(q)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p = 0.2, size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 0.26

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
q = []
for a in range(10000):
    q.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(q)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p = 0.4, size = 10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 2.14

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
q = []
for a in range(10000):
    q.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(q, bins = 300)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Статистические тесты

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Это будет наша генеральная совокупность. Посчитаем ее среднее

# %%
p = s.mean()
# Out:
# 10.032157374536052

# %% [markdown]
# Вытащим из нашей гс выборку из 50 элементов и сохраним ее

# %%
q1 = s.sample(50)

# %% [markdown]
# Посчитаем среднее нашей выборки

# %%
q1.mean()
# Out:
# 9.409648474268542

# %% [markdown]
# Вытащим из нашей гс вторую выборку из 50 элементов и сохраним ее

# %%
q2 = s.sample(50)

# %% [markdown]
# Посчитаем среднее второй выборки

# %%
q2.mean()
# Out:
# 9.756948078773505

# %% [markdown]
# Если бы мы не знали, что обе выборки из одной гс, то как мы бы ответили на вопрос: из одной ли гс обе выборки?
# Применили бы статистический тест. Какая нулевая гипотеза?

# %% [markdown]
# Начнем с t-теста Стьюдента

# %%
sps.ttest_ind(q1, q2)[1]
# Out:
# 0.49311964774357764

# %% [markdown]
# Отбрасываем нулевую гипотезу только при pvalue < 0.05

# %% [markdown]
# Проведем такие симуляции 10 000 раз, сохраняя полученные значения p-value в список

# %%
q = []
for a in range(10000):
    q.append(sps.ttest_ind(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Как будет выглядеть гистограмма p-значений?

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(q, bins = 100)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# Как часто наш тест будет ошибаться?

# %%
q = pd.Series(q)

# %%
q[q < 0.05].count()
# Out:
# 454

# %% [markdown]
# Сделать то же самое с непараметрическим тестом Манна-Уитни

# %%
q = []
for a in range(10000):
    q.append(sps.mannwhitneyu(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(q)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## Рассчет статистик

# %% [markdown]
# Загрузим датасет penguins из seaborn

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Посчитать двумя способами среднюю массу

# %%
df.body_mass_g.mean()
# Out:
# 4201.754385964912

# %%
df.body_mass_g.sum()/df.body_mass_g.count()
# Out:
# 4201.754385964912

# %% [markdown]
# Посчитать двумя способами дисперсию

# %%
df.body_mass_g.var()
# Out:
# 643131.0773267477

# %%
((df.body_mass_g.mean() - df.body_mass_g)**2/(df.body_mass_g.count()-1)).sum()
# Out:
# 643131.077326748

# %% [markdown]
# Посчитать двумя способами стандартное отклонение

# %%
df.body_mass_g.std()
# Out:
# 801.9545356980954

# %%
(((df.body_mass_g.mean() - df.body_mass_g)**2/(df.body_mass_g.count()-1)).sum())**(1/2)
# Out:
# 801.9545356980956

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Посчитать корреляцию для числовых значений датасета penguins

# %%
g = df.corr().round(2)

# %% [markdown]
# Оформить визуально таблицу

# %%
sns.heatmap(g, annot = True, cmap='crest')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Регрессия

# %% [markdown]
# Построить линию регрессии на диаграмме длина-масса

# %%
sns.regplot(x = 'body_mass_g', y = 'flipper_length_mm', data = df)
# Out:
# <AxesSubplot:xlabel='body_mass_g', ylabel='flipper_length_mm'>

# %% [markdown]
# Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm

# %%
sns.lmplot(x = 'bill_depth_mm', y = 'bill_length_mm', data = df)

# %% [markdown]
# Какая зависимость этих величин?

# %% [markdown]
# Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm. Отдельно для разных полов.

# %%
sns.lmplot(x = 'bill_depth_mm', y = 'bill_length_mm', data = df, hue='species')

# %% [markdown]
# Какая зависимость этих величин?

# %% [markdown]
# # СТАТИСТИКА

# %% [markdown]
# Импорт библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps

# %% [markdown]
# ## Генерация распределений

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 0, дисперсия - 1). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm().rvs(10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Посчитать сколько значений находится в хвостах по 2,5% (теоретически соответствуют значениям - 1,96).

# %%
s[s < -1.96].count()
# Out:
# 251

# %%
s[s > 1.96].count()
# Out:
# 252

# %% [markdown]
# Построить плотность вероятности и функцию распределения этой серии

# %%
sns.kdeplot(s);

# %%
sns.ecdfplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p=0.2, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(n=5, p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Соответствуют ли частоты ожидаемым?

# %% [markdown]
# ## Закон больших чисел

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 5 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 8.759798685068896

# %% [markdown]
# Сгенерировать список количеств отбираемых значений: [5, 10, 15, ..., 10000]

# %%
n = list(range(5, 5001, 5))

# %% [markdown]
# Для каждого значения из созданного списка посчитать среднее

# %%
means = []
for i in n:
    means.append(s.sample(i).mean())

# %% [markdown]
# Построить график: размер выборки - среднее

# %%
sns.lineplot(x=n, y=means)
sns.lineplot(x=n, y=s.mean());

# %% [markdown]
# ## Центральная предельная теорема

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 11.584454826882991

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(n=5, p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 1.88

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p=0.2, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 0.12

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 2.02

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# ## Статистические тесты

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Это будет наша генеральная совокупность. Посчитаем ее среднее

# %%
s.mean()
# Out:
# 9.985783491376441

# %% [markdown]
# Вытащим из нашей гс выборку из 50 элементов и сохраним ее

# %%
p_1 = s.sample(50)

# %% [markdown]
# Посчитаем среднее нашей выборки

# %%
p_1.mean()
# Out:
# 10.604332460139364

# %% [markdown]
# Вытащим из нашей гс вторую выборку из 50 элементов и сохраним ее

# %%
p_2 = s.sample(50)

# %% [markdown]
# Посчитаем среднее второй выборки

# %%
p_2.mean()
# Out:
# 9.786154725074061

# %% [markdown]
# Если бы мы не знали, что обе выборки из одной гс, то как мы бы ответили на вопрос: из одной ли гс обе выборки?
# Применили бы статистический тест. Какая нулевая гипотеза?

# %% [markdown]
# Начнем с t-теста Стьюдента

# %%
sps.ttest_ind(p_1, p_2)[1]
# Out:
# 0.19024369075609676

# %% [markdown]
# Отбрасываем нулевую гипотезу только при pvalue < 0.05

# %% [markdown]
# Проведем такие симуляции 10 000 раз, сохраняя полученные значения p-value в список

# %%
p_values = []
for _ in range(10000):
    p_values.append(sps.ttest_ind(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Как будет выглядеть гистограмма p-значений?

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(p_values, bins=20);

# %% [markdown]
# Как часто наш тест будет ошибаться?

# %% [markdown]
# Сделать то же самое с непараметрическим тестом Манна-Уитни

# %%
p_values = []
for _ in range(10000):
    p_values.append(sps.mannwhitneyu(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(p_values, bins=20);

# %% [markdown]
# ## Рассчет статистик

# %% [markdown]
# Загрузим датасет penguins из seaborn

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Посчитать двумя способами среднюю массу

# %%
df.body_mass_g.sum() / df.body_mass_g.count()
# Out:
# 4201.754385964912

# %%
df.body_mass_g.mean()
# Out:
# 4201.754385964912

# %% [markdown]
# Посчитать двумя способами дисперсию

# %%
((df.body_mass_g - df.body_mass_g.mean())**2).sum() / (df.body_mass_g.count() - 1)
# Out:
# 643131.077326748

# %%
df.body_mass_g.var()
# Out:
# 643131.0773267477

# %% [markdown]
# Посчитать двумя способами стандартное отклонение

# %%
(((df.body_mass_g - df.body_mass_g.mean())**2).sum() / (df.body_mass_g.count() - 1))**0.5
# Out:
# 801.9545356980956

# %%
df.body_mass_g.std()
# Out:
# 801.9545356980954

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Посчитать корреляцию для числовых значений датасета penguins

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# Оформить визуально таблицу

# %%
sns.heatmap(df.corr().round(2), annot=True, cmap='crest');

# %% [markdown]
# ## Регрессия

# %% [markdown]
# Построить линию регрессии на диаграмме длина-масса

# %%
sns.regplot(data=df, x='flipper_length_mm', y='body_mass_g');

# %%
Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='bill_length_mm');

# %% [markdown]
# Какая зависимость этих величин?

# %% [markdown]
# Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm. Отдельно для разных полов.

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='bill_length_mm', hue='species');

# %% [markdown]
# Какая зависимость этих величин?

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Импорт библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps

# %% [markdown]
# ## Генерация распределений

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 0, дисперсия - 1). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm().rvs(10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Посчитать сколько значений находится в хвостах по 2,5% (теоретически соответствуют значениям - 1,96).

# %%
s[s < -1.96].count()
# Out:
# 251

# %%
s[s > 1.96].count()
# Out:
# 252

# %% [markdown]
# Построить плотность вероятности и функцию распределения этой серии

# %%
sns.kdeplot(s);

# %%
sns.ecdfplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p=0.2, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(n=5, p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Соответствуют ли частоты ожидаемым?

# %% [markdown]
# ## Закон больших чисел

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 5 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 8.759798685068896

# %% [markdown]
# Сгенерировать список количеств отбираемых значений: [5, 10, 15, ..., 10000]

# %%
n = list(range(5, 5001, 5))

# %% [markdown]
# Для каждого значения из созданного списка посчитать среднее

# %%
means = []
for i in n:
    means.append(s.sample(i).mean())

# %% [markdown]
# Построить график: размер выборки - среднее

# %%
sns.lineplot(x=n, y=means)
sns.lineplot(x=n, y=s.mean());

# %% [markdown]
# ## Центральная предельная теорема

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 11.584454826882991

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(n=5, p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 1.88

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p=0.2, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 0.12

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 2.02

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# ## Статистические тесты

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Это будет наша генеральная совокупность. Посчитаем ее среднее

# %%
s.mean()
# Out:
# 9.985783491376441

# %% [markdown]
# Вытащим из нашей гс выборку из 50 элементов и сохраним ее

# %%
p_1 = s.sample(50)

# %% [markdown]
# Посчитаем среднее нашей выборки

# %%
p_1.mean()
# Out:
# 10.604332460139364

# %% [markdown]
# Вытащим из нашей гс вторую выборку из 50 элементов и сохраним ее

# %%
p_2 = s.sample(50)

# %% [markdown]
# Посчитаем среднее второй выборки

# %%
p_2.mean()
# Out:
# 9.786154725074061

# %% [markdown]
# Если бы мы не знали, что обе выборки из одной гс, то как мы бы ответили на вопрос: из одной ли гс обе выборки?
# Применили бы статистический тест. Какая нулевая гипотеза?

# %% [markdown]
# Начнем с t-теста Стьюдента

# %%
sps.ttest_ind(p_1, p_2)[1]
# Out:
# 0.19024369075609676

# %% [markdown]
# Отбрасываем нулевую гипотезу только при pvalue < 0.05

# %% [markdown]
# Проведем такие симуляции 10 000 раз, сохраняя полученные значения p-value в список

# %%
p_values = []
for _ in range(10000):
    p_values.append(sps.ttest_ind(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Как будет выглядеть гистограмма p-значений?

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(p_values, bins=20);

# %% [markdown]
# Как часто наш тест будет ошибаться?

# %% [markdown]
# Сделать то же самое с непараметрическим тестом Манна-Уитни

# %%
p_values = []
for _ in range(10000):
    p_values.append(sps.mannwhitneyu(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(p_values, bins=20);

# %% [markdown]
# ## Рассчет статистик

# %% [markdown]
# Загрузим датасет penguins из seaborn

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Посчитать двумя способами среднюю массу

# %%
df.body_mass_g.sum() / df.body_mass_g.count()
# Out:
# 4201.754385964912

# %%
df.body_mass_g.mean()
# Out:
# 4201.754385964912

# %% [markdown]
# Посчитать двумя способами дисперсию

# %%
((df.body_mass_g - df.body_mass_g.mean())**2).sum() / (df.body_mass_g.count() - 1)
# Out:
# 643131.077326748

# %%
df.body_mass_g.var()
# Out:
# 643131.0773267477

# %% [markdown]
# Посчитать двумя способами стандартное отклонение

# %%
(((df.body_mass_g - df.body_mass_g.mean())**2).sum() / (df.body_mass_g.count() - 1))**0.5
# Out:
# 801.9545356980956

# %%
df.body_mass_g.std()
# Out:
# 801.9545356980954

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Посчитать корреляцию для числовых значений датасета penguins

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# Оформить визуально таблицу

# %%
sns.heatmap(df.corr().round(2), annot=True, cmap='crest');

# %% [markdown]
# ## Регрессия

# %% [markdown]
# Построить линию регрессии на диаграмме длина-масса

# %%
sns.regplot(data=df, x='flipper_length_mm', y='body_mass_g');

# %%
Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='bill_length_mm');

# %% [markdown]
# Какая зависимость этих величин?

# %% [markdown]
# Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm. Отдельно для разных полов.

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='bill_length_mm', hue='species');

# %% [markdown]
# Какая зависимость этих величин?

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Импорт библиотек

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as sps

# %% [markdown]
# ## Генерация распределений

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 0, дисперсия - 1). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm().rvs(10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Посчитать сколько значений находится в хвостах по 2,5% (теоретически соответствуют значениям - 1,96).

# %%
s[s < -1.96].count()
# Out:
# 251

# %%
s[s > 1.96].count()
# Out:
# 252

# %% [markdown]
# Построить плотность вероятности и функцию распределения этой серии

# %%
sns.kdeplot(s);

# %%
sns.ecdfplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p=0.2, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(n=5, p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Соответствуют ли частоты ожидаемым?

# %% [markdown]
# ## Закон больших чисел

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 5 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 8.759798685068896

# %% [markdown]
# Сгенерировать список количеств отбираемых значений: [5, 10, 15, ..., 10000]

# %%
n = list(range(5, 5001, 5))

# %% [markdown]
# Для каждого значения из созданного списка посчитать среднее

# %%
means = []
for i in n:
    means.append(s.sample(i).mean())

# %% [markdown]
# Построить график: размер выборки - среднее

# %%
sns.lineplot(x=n, y=means)
sns.lineplot(x=n, y=s.mean());

# %% [markdown]
# ## Центральная предельная теорема

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(5).mean()
# Out:
# 11.584454826882991

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из биномиального распределения c n = 5 и p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.binom.rvs(n=5, p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 1.88

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из распределения Бернулли p=0.2. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.bernoulli.rvs(p=0.2, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 0.12

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# Сгенерировать 10000 значений из геометрического распределения c p = 0.4. Сохранить в падасовскую серию

# %%
s = pd.Series(sps.geom.rvs(p=0.4, size=10000))

# %% [markdown]
# Построить гистограмму этой серии

# %%
sns.histplot(s);

# %% [markdown]
# Из серии s выбрать 50 значений и посчитать их среднее

# %%
s.sample(50).mean()
# Out:
# 2.02

# %% [markdown]
# Сделать это 10000 раз сохраняя значения среднего в список

# %%
means = []
for _ in range(10000):
    means.append(s.sample(50).mean())

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(means);

# %% [markdown]
# ## Статистические тесты

# %% [markdown]
# Сгенерировать 10000 значений из нормального распределения (среднее - 10, дисперсия - 3). Сохранить в падасовскую серию

# %%
s = pd.Series(sps.norm.rvs(loc=10, scale=3, size=10000))

# %% [markdown]
# Это будет наша генеральная совокупность. Посчитаем ее среднее

# %%
s.mean()
# Out:
# 9.985783491376441

# %% [markdown]
# Вытащим из нашей гс выборку из 50 элементов и сохраним ее

# %%
p_1 = s.sample(50)

# %% [markdown]
# Посчитаем среднее нашей выборки

# %%
p_1.mean()
# Out:
# 10.604332460139364

# %% [markdown]
# Вытащим из нашей гс вторую выборку из 50 элементов и сохраним ее

# %%
p_2 = s.sample(50)

# %% [markdown]
# Посчитаем среднее второй выборки

# %%
p_2.mean()
# Out:
# 9.786154725074061

# %% [markdown]
# Если бы мы не знали, что обе выборки из одной гс, то как мы бы ответили на вопрос: из одной ли гс обе выборки?
# Применили бы статистический тест. Какая нулевая гипотеза?

# %% [markdown]
# Начнем с t-теста Стьюдента

# %%
sps.ttest_ind(p_1, p_2)[1]
# Out:
# 0.19024369075609676

# %% [markdown]
# Отбрасываем нулевую гипотезу только при pvalue < 0.05

# %% [markdown]
# Проведем такие симуляции 10 000 раз, сохраняя полученные значения p-value в список

# %%
p_values = []
for _ in range(10000):
    p_values.append(sps.ttest_ind(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Как будет выглядеть гистограмма p-значений?

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(p_values, bins=20);

# %% [markdown]
# Как часто наш тест будет ошибаться?

# %% [markdown]
# Сделать то же самое с непараметрическим тестом Манна-Уитни

# %%
p_values = []
for _ in range(10000):
    p_values.append(sps.mannwhitneyu(s.sample(50), s.sample(50))[1])

# %% [markdown]
# Построить гистограмму этого списка

# %%
sns.histplot(p_values, bins=20);

# %% [markdown]
# ## Рассчет статистик

# %% [markdown]
# Загрузим датасет penguins из seaborn

# %%
df = sns.load_dataset('penguins')

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# Посчитать двумя способами среднюю массу

# %%
df.body_mass_g.sum() / df.body_mass_g.count()
# Out:
# 4201.754385964912

# %%
df.body_mass_g.mean()
# Out:
# 4201.754385964912

# %% [markdown]
# Посчитать двумя способами дисперсию

# %%
((df.body_mass_g - df.body_mass_g.mean())**2).sum() / (df.body_mass_g.count() - 1)
# Out:
# 643131.077326748

# %%
df.body_mass_g.var()
# Out:
# 643131.0773267477

# %% [markdown]
# Посчитать двумя способами стандартное отклонение

# %%
(((df.body_mass_g - df.body_mass_g.mean())**2).sum() / (df.body_mass_g.count() - 1))**0.5
# Out:
# 801.9545356980956

# %%
df.body_mass_g.std()
# Out:
# 801.9545356980954

# %% [markdown]
# ## Корреляционный анализ

# %% [markdown]
# Посчитать корреляцию для числовых значений датасета penguins

# %%
df.corr()
# Out:
#                    bill_length_mm  bill_depth_mm  flipper_length_mm  \
# bill_length_mm           1.000000      -0.235053           0.656181
# bill_depth_mm           -0.235053       1.000000          -0.583851
# flipper_length_mm        0.656181      -0.583851           1.000000
# body_mass_g              0.595110      -0.471916           0.871202
#
#                    body_mass_g
# bill_length_mm        0.595110
# bill_depth_mm        -0.471916
# flipper_length_mm     0.871202
# body_mass_g           1.000000

# %% [markdown]
# Оформить визуально таблицу

# %%
sns.heatmap(df.corr().round(2), annot=True, cmap='crest');

# %% [markdown]
# ## Регрессия

# %% [markdown]
# Построить линию регрессии на диаграмме длина-масса

# %%
sns.regplot(data=df, x='flipper_length_mm', y='body_mass_g');

# %%
Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='bill_length_mm');

# %% [markdown]
# Какая зависимость этих величин?

# %% [markdown]
# Построить линию регрессии на диаграмме bill_depth_mm-bill_length_mm. Отдельно для разных полов.

# %%
sns.lmplot(data=df, x='bill_depth_mm', y='bill_length_mm', hue='species');

# %% [markdown]
# Какая зависимость этих величин?

# %%
df.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
